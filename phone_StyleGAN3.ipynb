# %%
# !python -V
# Out:
# Python 3.11.5

# %%
# !nvidia-smi
# Out:
# Thu Nov 23 02:11:04 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.01                 Driver Version: 546.01       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4090      WDDM  | 00000000:01:00.0 Off |                  Off |
# |  0%   35C    P8              12W / 450W |      0MiB / 24564MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:41:10_Pacific_Daylight_Time_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !git clone https://github.com/NVlabs/stylegan3

# %%
# model_save_dir : google drive에 model 저장 path
# train_data_dir : 학습에 사용할 data path (directory, not zip)
# model_save_dir = 'C://Users/user/Desktop/딥러닝/GAN/model'
train_data_dir = 'C://Users/user/Desktop/workspace/stylegan3/image2'

# %%
pwd
# Out:
# 'C:\\Users\\user\\Desktop\\workspace\\stylegan3'

# %%
# import os

# os.chdir('stylegan3')
# os.getcwd()

# %%
import shutil
import os

os.mkdir('train_dataset')

# %%
pwd
# Out:
# 'C:\\Users\\user\\Desktop\\workspace\\stylegan3'

# %%
train_data_dir
# Out:
# 'C://Users/user/Desktop/workspace/stylegan3/image2'

# %%
# import os

# # 디렉토리 경로 설정
# directory_path = 'C://Users/user/Desktop/workspace/stylegan3/image2'

# # 디렉토리 내의 모든 파일에 대해 반복
# for idx, filename in enumerate(os.listdir(directory_path)):
#     # 파일 확장자 확인 (이미지 파일만 처리)
#     if filename.endswith(('.png', '.jpg', '.jpeg')):
#         # 숫자로 파일 이름 변경
#         new_filename = f"{idx + 1}.jpg"

#         # 기존 파일 경로 및 새 파일 경로 설정
#         old_filepath = os.path.join(directory_path, filename)
#         new_filepath = os.path.join(directory_path, new_filename)

#         # 파일 이름 변경
#         os.rename(old_filepath, new_filepath)

#         print(f"{filename} -> {new_filename}")

# %%
from glob import glob
# from tqdm import tqdm
import matplotlib.pyplot as plt
import cv2

dst = 'train_dataset/'

org_td_list = [ele for ele in glob(os.path.join(train_data_dir, '**'), recursive=True) if ele.endswith('.jpg')]

# substring_to_remove = 'C://Users/user/Desktop/workspace/stylegan3/'

# # 각 문자열에서 부분을 삭제
# org_td_list = [string.replace(substring_to_remove, '') for string in org_td_list]

img_name = os.path.basename(org_td_list[50])

img = cv2.imread(org_td_list[50].encode('utf-8').decode('utf-8'))
img = cv2.resize(img, (128, 128))
cv2.imwrite(os.path.join(dst, img_name), img)
plt.imshow(img)

# %%
org_td_list
# Out:
# ['C://Users/user/Desktop/workspace/stylegan3/image2\\1.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\10.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\100.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\101.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\102.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\103.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\104.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\105.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\106.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\107.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\108.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\109.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\11.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\110.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\111.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\112.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\12.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\13.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\14.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\15.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\16.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\17.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\18.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\19.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\2.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\20.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\21.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\22.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\23.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\24.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\25.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\26.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\27.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\28.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\29.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\3.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\30.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\31.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\32.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\33.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\34.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\35.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\36.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\37.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\38.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\39.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\4.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\40.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\41.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\42.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\43.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\44.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\45.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\46.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\47.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\48.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\49.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\5.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\50.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\51.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\52.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\53.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\54.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\55.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\56.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\57.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\58.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\59.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\6.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\60.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\61.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\62.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\63.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\64.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\65.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\66.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\67.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\68.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\69.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\7.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\70.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\71.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\72.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\73.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\74.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\75.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\76.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\77.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\78.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\79.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\8.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\80.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\81.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\82.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\83.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\84.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\85.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\86.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\87.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\88.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\89.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\9.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\90.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\91.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\92.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\93.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\94.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\95.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\96.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\97.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\98.jpg',
#  'C://Users/user/Desktop/workspace/stylegan3/image2\\99.jpg']

# %%
# substring_to_remove = 'C://Users/user/Desktop/딥러닝/GAN/stylegan3'

# # 각 문자열에서 부분을 삭제
# org_td_list = [string.replace(substring_to_remove, '') for string in org_td_list]

# %%
for img_path in org_td_list:
    img_name = os.path.basename(img_path)
    img = cv2.imread(img_path)
    img = cv2.resize(img, (128, 128))
    cv2.imwrite(os.path.join(dst, img_name), img)

# %%
dst_td_list = [ele for ele in glob(os.path.join(dst, '**'), recursive=True) if ele.endswith('.jpg')]

# %%
for img_path in dst_td_list:
    if cv2.imread(img_path).shape != (128, 128, 3):
        print(os.path.basename(img_path), cv2.imread(img_path).shape)

# %%
# !python dataset_tool.py --source=./train_dataset --dest=./train_dataset/train.zip --resolution=128x128
# Out:
#   0%|          | 0/112 [00:00<?, ?it/s]
# 100%|##########| 112/112 [00:00<00:00, 1750.91it/s]

# %%
# os.environ['model_save_dir'] = model_save_dir

# %%
pip install --upgrade psutil
# Out:
# Requirement already satisfied: psutil in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (5.9.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python train.py --outdir=./model_output --cfg=stylegan2 --data=./train_dataset/train.zip --gpus=1 --batch=32 --gamma=5.9 --mirror=1 --kimg=10000 --snap=50 --workers=15
